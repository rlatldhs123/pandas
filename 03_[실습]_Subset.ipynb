# %% [markdown]
# <a href="https://colab.research.google.com/github/rlatldhs123/pandas/blob/main/03_%5B%EC%8B%A4%EC%8A%B5%5D_Subset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### [참고] <a href="https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf">Pandas Cheat Sheet</a>

# %% [markdown]
# #### 1. 라이브러리 로드

# %%
from google.colab import drive
drive.mount('/content/gdrive')  # 이 작업은 나의 구글 드라이브를 연동하는 작업이다
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd

# %% [markdown]
# #### 2. sample.xlsx
#
# #### 1) 데이터 프레임 생성

# %%
sample_df=pd.read_excel('/content/gdrive/MyDrive/Colab Notebooks/data/sample.xlsx')
sample_df
# Out:
#    Sap Co.        대리점 영업사원       전월       금월  TEAM  총 판매수량
# 0   KI1316    경기수원대리점  이기정  1720000  2952000     1     123
# 1   KI1451    충청홍성대리점  정미진  4080000  2706000     2     220
# 2   KI1534    경기화성대리점  경인선   600000  2214000     1     320
# 3   KI1636    강원속초대리점  이동권  3720000  2870000     3     110
# 4   KI1735    경기안양대리점  강준석  4800000  2296000     1     134
# 5   KI1875   제주제주시대리점  민경수  3420000  2346000     4     210
# 6   KI1917    경기광주대리점  김진혜  1292000  1518000     1     110
# 7   KI2032    경기평택대리점  고유정  2736000  2139000     2      90
# 8   KI2153   경기의정부대리점  김은향  1368000  2484000     1     183
# 9   KI2214    경기성남대리점  이준수  1976000  1518000     3      73
# 10  KI2313  제주서귀포시대리점  온지수   152000   945000     1      52
# 11  KI2433    경기계양대리점  이희영  1833000  1404000     1     110
# 12  KI2512    경기평촌대리점  강백호  4320000  2312000     3     240
# 13  KI2671  제주서귀포시대리점  주은명  4040000  4760000     4      50
# 14  KI2776   경기남양주대리점  김수진  8160000  4352000     2     354
# ...

# %% [markdown]
# #### 2) 앞 쪽의 5행 조회

# %%
sample_df.loc[:5]
# Out:
#   Sap Co.       대리점 영업사원       전월       금월  TEAM  총 판매수량
# 0  KI1316   경기수원대리점  이기정  1720000  2952000     1     123
# 1  KI1451   충청홍성대리점  정미진  4080000  2706000     2     220
# 2  KI1534   경기화성대리점  경인선   600000  2214000     1     320
# 3  KI1636   강원속초대리점  이동권  3720000  2870000     3     110
# 4  KI1735   경기안양대리점  강준석  4800000  2296000     1     134
# 5  KI1875  제주제주시대리점  민경수  3420000  2346000     4     210

# %% [markdown]
# #### 3) 뒤 쪽의 3행 조회

# %%
sample_df.loc[]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/range.py in get_loc(self, key)
#     344             try:
# --> 345                 return self._range.index(new_key)
#     346             except ValueError as err:
#
# ValueError: -3 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-a29d216c5564> in <cell line: 1>()
# ----> 1 sample_df.loc[-3]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1101
#    1102             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1103             return self._getitem_axis(maybe_callable, axis=axis)
#    1104
#    1105     def _is_scalar_access(self, key: tuple):
#
# ...

# %% [markdown]
# #### 4) 금월 컬럼에서 값이 큰 3개 행 조회

# %%
sample_df.nlargest(3,"금월")
# Out:
#    Sap Co.        대리점 영업사원       전월       금월  TEAM  총 판매수량
# 18  KI3131    경기하남대리점  김민정  2750000  7268000     3     293
# 16  KI2910    강원춘천대리점  김은향  4800000  4896000     1     176
# 13  KI2671  제주서귀포시대리점  주은명  4040000  4760000     4      50

# %% [markdown]
# #### 5) 전월 컬럼에서 값이 가장 작은 5개 행 조회

# %%
sample_df.nsmallest(5,"전월")
# Out:
#    Sap Co.        대리점 영업사원       전월       금월  TEAM  총 판매수량
# 10  KI2313  제주서귀포시대리점  온지수   152000   945000     1      52
# 2   KI1534    경기화성대리점  경인선   600000  2214000     1     320
# 6   KI1917    경기광주대리점  김진혜  1292000  1518000     1     110
# 8   KI2153   경기의정부대리점  김은향  1368000  2484000     1     183
# 0   KI1316    경기수원대리점  이기정  1720000  2952000     1     123

# %% [markdown]
# #### 6) 총 판매수량이 250보다 큰 대리점 추출

# %%
sample_df[sample_df["총 판매수량"]> 250]
# Out:
#    Sap Co.       대리점 영업사원       전월       금월  TEAM  총 판매수량
# 2   KI1534   경기화성대리점  경인선   600000  2214000     1     320
# 14  KI2776  경기남양주대리점  김수진  8160000  4352000     2     354
# 18  KI3131   경기하남대리점  김민정  2750000  7268000     3     293

# %% [markdown]
# #### 7) 행 전체를 포함하고, 컬럼은 대리점, 영업사원, 금월 추출

# %%
sample_df.loc[:][["대리점","영업사원","금월"]]
# Out:
#           대리점 영업사원       금월
# 0     경기수원대리점  이기정  2952000
# 1     충청홍성대리점  정미진  2706000
# 2     경기화성대리점  경인선  2214000
# 3     강원속초대리점  이동권  2870000
# 4     경기안양대리점  강준석  2296000
# 5    제주제주시대리점  민경수  2346000
# 6     경기광주대리점  김진혜  1518000
# 7     경기평택대리점  고유정  2139000
# 8    경기의정부대리점  김은향  2484000
# 9     경기성남대리점  이준수  1518000
# 10  제주서귀포시대리점  온지수   945000
# 11    경기계양대리점  이희영  1404000
# 12    경기평촌대리점  강백호  2312000
# 13  제주서귀포시대리점  주은명  4760000
# 14   경기남양주대리점  김수진  4352000
# 15   경기구리시대리점  박진형  3400000
# 16    강원춘천대리점  김은향  4896000
# 17    강원영동대리점  전수창  3128000
# 18    경기하남대리점  김민정  7268000
# 19    강원포천대리점  서가은  4740000

# %% [markdown]
# #### 8) loc 이용 : sample_df 에서 2, 4번 인덱스를 가진 행 추출

# %%
sample_df.loc[[2,4]]
# Out:
#   Sap Co.      대리점 영업사원       전월       금월  TEAM  총 판매수량
# 2  KI1534  경기화성대리점  경인선   600000  2214000     1     320
# 4  KI1735  경기안양대리점  강준석  4800000  2296000     1     134

# %% [markdown]
# #### 9) iloc 이용 : sample_df 에서 2, 4번 인덱스를 가진 행 추출

# %%
sample_df.iloc[[2,4]]
# Out:
#   Sap Co.      대리점 영업사원       전월       금월  TEAM  총 판매수량
# 2  KI1534  경기화성대리점  경인선   600000  2214000     1     320
# 4  KI1735  경기안양대리점  강준석  4800000  2296000     1     134

# %% [markdown]
# #### 10) loc 이용 : sample_df 에서 3, 4, 5번 인덱스를 가진 행 추출(대리점,영업사원,총 판매수량 컬럼만)

# %%
sample_df.loc[3:5][["대리점","영업사원","총 판매수량"]]
# Out:
#         대리점 영업사원  총 판매수량
# 3   강원속초대리점  이동권     110
# 4   경기안양대리점  강준석     134
# 5  제주제주시대리점  민경수     210

# %% [markdown]
# #### 11) 전체 행 추출 : 전월,금월 컬럼만(앞쪽 데이터 5개만 보여주기)

# %%
sample_df.iloc[:5][["전월","금월"]]
# Out:
#         전월       금월
# 0  1720000  2952000
# 1  4080000  2706000
# 2   600000  2214000
# 3  3720000  2870000
# 4  4800000  2296000

# %% [markdown]
# #### 12)  filter 를 이용하여 컬럼명에 "월"이 들어간 컬럼을 추출하기

# %%
sample_df.filter(like="월")
# Out:
#          전월       금월
# 0   1720000  2952000
# 1   4080000  2706000
# 2    600000  2214000
# 3   3720000  2870000
# 4   4800000  2296000
# 5   3420000  2346000
# 6   1292000  1518000
# 7   2736000  2139000
# 8   1368000  2484000
# 9   1976000  1518000
# 10   152000   945000
# 11  1833000  1404000
# 12  4320000  2312000
# 13  4040000  4760000
# 14  8160000  4352000
# 15  6000000  3400000
# 16  4800000  4896000
# 17  4560000  3128000
# 18  2750000  7268000
# 19  2420000  4740000

# %% [markdown]
# #### 3. train.xlsx
#
# #### 1) 데이터 프레임 생성

# %%
sample_df=pd.read_excel('/content/gdrive/MyDrive/Colab Notebooks/data/train.xlsx')
sample_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# #### 2) 앞 쪽의 데이터 5개 조회

# %%
sample_df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# #### 3) 뒤 쪽의 데이터 5개 조회

# %%
sample_df.tail(5)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#      Gender   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# #### 4) Age 값이 가장큰 12개행 조회
#
# *   항목 추가
# *   항목 추가

# %%
sample_df
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
# 27            28         0       1      Fortune, Mr. Charles Alexander
#
#      Gender   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
# 27     male  19.0      3      2     19950  263.0000  C23 C25 C27        S

# %% [markdown]
# #### 5) Age 컬럼 값이 가장 작은 3개 행 조회

# %%
sample_df.loc[sample_df["Age"].nsmallest(3).index]
# Out:
#      PassengerId  Survived  Pclass                             Name  Gender  \
# 803          804         1       3  Thomas, Master. Assad Alexander    male
# 755          756         1       2        Hamalainen, Master. Viljo    male
# 469          470         1       3    Baclini, Miss. Helene Barbara  female
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 803  0.42      0      1    2625   8.5167   NaN        C
# 755  0.67      1      1  250649  14.5000   NaN        S
# 469  0.75      2      1    2666  19.2583   NaN        C
