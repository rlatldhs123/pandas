# %% [markdown]
# <a href="https://colab.research.google.com/github/rlatldhs123/pandas/blob/main/03_Subset_1)_rows.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### [참고] <a href="https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf">Pandas Cheat Sheet</a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1. row 기준
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 1) head / tail

# %%
# DataFrame 생성
df = pd.DataFrame(
    {
        "a": [4, 5, 6, 8, np.nan],
        "b": [7, 8, np.nan, 9, 9],
        "c": [10, 11, 12, np.nan, 12],
    },
    index=[1, 2, 3, 4, 5]
)
df
# Out:
#      a    b     c
# 1  4.0  7.0  10.0
# 2  5.0  8.0  11.0
# 3  6.0  NaN  12.0
# 4  8.0  9.0   NaN
# 5  NaN  9.0  12.0

# %%
# Out:
#      a    b     c
# 1  4.0  7.0  10.0
# 2  5.0  8.0  11.0
# 3  6.0  NaN  12.0
# 4  6.0  9.0   NaN
# 5  NaN  9.0  12.0

# %%
# Out:
#      a    b     c
# 1  4.0  7.0  10.0
# 2  5.0  8.0  11.0

# %%
# Out:
#      a    b     c
# 4  6.0  9.0   NaN
# 5  NaN  9.0  12.0

# %% [markdown]
# ### 2) sample

# %%
frac =: 특정 비율

df.sample(frac=0.5)
# Out:
#      a    b     c
# 4  6.0  9.0   NaN
# 5  NaN  9.0  12.0

# %%
# n의 개수는 전체의 행 수를 넘어서 지정하면 에러 발생
# 임의로 3개 가져오기

df.sample(n=3)
# Out:
#      a    b     c
# 5  NaN  9.0  12.0
# 1  4.0  7.0  10.0
# 3  6.0  NaN  12.0

# %% [markdown]
# ### 3) nlargest / nsmallest

# %%
df.nlargest?

# %%
# Out:
#      a    b     c
# 3  6.0  NaN  12.0
# 4  6.0  9.0   NaN
# 2  5.0  8.0  11.0

# %%
df.nlargest(3,"a") # a 컬럼에서 제일큰거 3개
# Out:
#      a    b     c
# 4  8.0  9.0   NaN
# 3  6.0  NaN  12.0
# 2  5.0  8.0  11.0

# %%
df.nsmallest(2,"a") # a 컬럼에서 제일 작은거 2개 가져와봐
# Out:
#      a    b     c
# 1  4.0  7.0  10.0
# 2  5.0  8.0  11.0

# %% [markdown]
# ### 4) 중복 행 제거 : drop_duplicates()
#
#
# ```
# df.drop_duplicates(
#     subset: Union[Hashable, Sequence[Hashable], NoneType] = None,
#     keep: Union[str, bool] = 'first',
#     inplace: bool = False,
#     ignore_index: bool = False,
# ) -> Union[ForwardRef('DataFrame'), NoneType]
# ```

# %%
# Out:
#    a  b   c
# a  4  7  10
# b  5  8  11
# c  6  9  12
# d  6  9  12

# %%
# Out:
#    a  b   c
# a  4  7  10
# b  5  8  11
# c  6  9  12

# %%
df
# Out:
#    a  b   c
# a  4  7  10
# b  5  8  11
# c  6  9  12
# d  6  9  12

# %%
df
# Out:
#    a  b   c
# a  4  7  10
# b  5  8  11
# c  6  9  12

# %% [markdown]
# ### 5) 불린 인덱싱

# %%
# Out:
#     name  age        job
# 0   John   25    student
# 1   Nate   34    teacher
# 2  Jenny   30  developer

# %%
# Out:
# 0    False
# 1     True
# 2     True
# Name: age, dtype: bool

# %%
# Out:
#     name  age        job
# 1   Nate   34    teacher
# 2  Jenny   30  developer

# %%
# Out:
#    name  age      job
# 1  Nate   34  teacher

# %%
# Out:
#    name  age      job
# 1  Nate   34  teacher

# %%
# Out:
#     name  age        job
# 2  Jenny   30  developer

# %% [markdown]
# ### 6) query()

# %%
# Out:
#     name  age        job
# 1   Nate   34    teacher
# 2  Jenny   30  developer

# %%
# Out:
#    name  age      job
# 1  Nate   34  teacher

# %% [markdown]
# #### [실습] friend_df

# %% [markdown]
# #### 1) head()

# %%
# Out:
#     name  age        job
# 0   John   25    student
# 1   Nate   34    teacher
# 2  Jenny   30  developer

# %%
# Out:
#     name  age        job
# 0   John   25    student
# 1   Nate   34    teacher
# 2  Jenny   30  developer

# %% [markdown]
# #### 2) tail()

# %%
# Out:
#     name  age        job
# 0   John   25    student
# 1   Nate   34    teacher
# 2  Jenny   30  developer

# %%
# Out:
#     name  age        job
# 0   John   25    student
# 1   Nate   34    teacher
# 2  Jenny   30  developer

# %% [markdown]
# #### 3) nlargest()

# %%
# Out:
#    name  age      job
# 1  Nate   34  teacher

# %% [markdown]
# #### 4) nsmallest()

# %%
# Out:
#    name  age      job
# 0  John   25  student

# %% [markdown]
# #### 5) sample()

# %%
# Out:
#    name  age      job
# 1  Nate   34  teacher

# %%
# Out:
#     name  age        job
# 1   Nate   34    teacher
# 2  Jenny   30  developer

# %% [markdown]
# #### [실습] drop_duplicates()

# %%
# Out:
#      name             major  gender
# 0    John  Computer Science    male
# 1    Nate  Computer Science    male
# 2  Edward  Computer Science    male
# 3    Zara        Psychology  female
# 4    John  Computer Science    male

# %%
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
# Out:
#      name             major  gender
# 0    John  Computer Science    male
# 1    Nate  Computer Science    male
# 2  Edward  Computer Science    male
# 3    Zara        Psychology  female

# %%
# Out:
#      name             major  gender
# 0    John  Computer Science    male
# 1    Nate  Computer Science    male
# 2  Edward  Computer Science    male
# 3    Zara        Psychology  female
# 4   Wendy         Economics  female
# 5    Nate              None    male
# 6    John         Economics    male

# %%
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# dtype: bool

# %%
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6     True
# dtype: bool

# %%
# Out:
#      name             major  gender
# 0    John  Computer Science    male
# 1    Nate  Computer Science    male
# 2  Edward  Computer Science    male
# 3    Zara        Psychology  female
# 4   Wendy         Economics  female
